# %%
print("lets start with python")
# Out:
# lets start with python

# %% [markdown]
# ## for conditions manage proper spacing

# %%
age=int(input("what is your age:"))

if(age>18):
    print("elegible for DL")
else:
    print("Not elegible")
# Out:
# Not elegible

# %% [markdown]
# ## line break in python use \

# %%
1+2+3+4+5+\
6+7
# Out:
# 28
